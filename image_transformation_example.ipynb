# %%
# %matplotlib inline
from image_transformer import ImageTransfomer
import numpy as np
from utils import display_image

# %%
image_transformer = ImageTransfomer('images/*.jpg',(500,400))

# %%
identity_transformation = np.array([[1.,0.,0.],[0.,1.,0.]])
image_transformer.interpolate_all_images(identity_transformation)
display_image(image_transformer.transformed_images[0])

# %%
affine_transformation = np.array([[0.707,-.707,-.3],[.707,.707,-.3]])
image_transformer.interpolate_all_images(affine_transformation)
display_image(image_transformer.transformed_images[0])
